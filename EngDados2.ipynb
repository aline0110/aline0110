# %% [markdown]
# <a href="https://colab.research.google.com/github/aline0110/aline0110/blob/main/EngDados2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('livros.csv')
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
df.shape
# Out:
# (174, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Book                           174 non-null    object
#  1   Author(s)                      174 non-null    object
#  2   Original language              174 non-null    object
#  3   First published                174 non-null    int64
#  4   Approximate sales in millions  174 non-null    float64
#  5   Genre                          118 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 8.3+ KB

# %%
df.to_sql()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-3979413678.py in <cell line: 0>()
# ----> 1 df.to_sql()
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# TypeError: NDFrame.to_sql() missing 2 required positional arguments: 'name' and 'con'

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/livros.csv')
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
df.shape
# Out:
# (174, 6)

# %%
import pandas as pd
